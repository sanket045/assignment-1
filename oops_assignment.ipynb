# %% [raw]
# *********************   Task-1  s***************************
#
#
# 1. Create a function which will take a list as an argument and return the product of all the numbers
# after creating a flat list.
# Use the below-given list as an argument for your function.
# list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45,
# 22, 61, 34)}, [56, 'data science'], 'Machine Learning']
# Note: you must extract numeric keys and values of the dictionary also.
#
# Ans:def product_of_numbers(lst):
#     flattened_list = []
#     for item in lst:
#         if type(item) == list:
#             flattened_list.extend(item)
#         elif type(item) == dict:
#             for key, value in item.items():
#                 if isinstance(key, (int, float, complex)):
#                     flattened_list.append(key)
#                 if isinstance(value, (int, float, complex)):
#                     flattened_list.append(value)
#         else:
#             flattened_list.append(item)
#     product = 1
#     for num in flattened_list:
#         if isinstance(num, (int, float, complex)):
#             product *= num
#     return product
#
#   pro=product_of_numbers([1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89],
#   4: (45,22, 61, 34)}, [56, 'data science'], 'Machine Learning'])
#   pro
#
#   Output:- 0
#
# Q2. Write a python program for encrypting a message sent to you by your friend. The logic of encryption
# should be such that, for a the output should be z. For b, the output should be y. For c, the output should
# be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation
# marks unchanged.
# Input Sentence: I want to become a Data Scientist.
# Encrypt the above input sentence using the program you just created.
# Note: Convert the given input sentence into lowercase before encrypting. The final output should be
# lowercase.
#
# Ans:- def encrypt(message):
#     message = message.lower()
#     result = ""
#     for char in message:
#         if char == " ":
#             result += "$"
#         elif char.isalpha():
#             result += chr(ord('a') + (25 - (ord(char) - ord('a'))))
#         else:
#             result += char
#     return result
#
#
# input_sentence = "I want to become a Data Scientist."
# encrypted_sentence = encrypt(input_sentence)
# print(encrypted_sentence)
